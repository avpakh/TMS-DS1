# %% [markdown]
# <a href="https://colab.research.google.com/github/avpakh/TMS-DS1/blob/main/%22%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5%22_%D0%9C%D0%B0%D1%82%D0%B5%D0%BC%D0%B0%D1%82%D0%B8%D0%BA%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Часть 1

# %% [markdown]
# Сколько чисел от 1 к 20 включительно делятся на 2?

# %%
count_z = 0

for k in range(20,0,-1):
  if k%2 ==0:
    count_z += 1   
print (count_z)
# Out:
# 10

# %% [markdown]
# Сколько чисел от 1 к 20 включительно делятся на 3?

# %%
count_z = 0

for k in range(20,0,-1):
  if k%3 ==0:
    count_z += 1   
print (count_z)
# Out:
# 6

# %% [markdown]
# Сколько чисел от 1 к 20 включительно делятся на 2 или на 3?

# %%
count_z = 0

for k in range(20,0,-1):
  if k%2 ==0 and k%3 ==0:
    count_z += 1   
print (count_z)
# Out:
# 3

# %% [markdown]
# ### Часть 2

# %% [markdown]
# ```
# for _ in range(7):
#         print("Hello world!")
# for _ in range(6):
#         print("Hello world!")
# ```
#
# Сколько раз будет напечетана строка `"Hello world!"`?

# %%
13

# %% [markdown]
# ```
# for _ in range(8):
#         print("Hi!")
# for _ in range(4):
#         print("Hi!")
# for _ in range(7):
#         print("Hi!")
# ```
#
# Сколько раз будет напечетана строка `"Hi!"`?

# %%
19

# %% [markdown]
# ### Часть 3

# %% [markdown]
# Найдите |A| в множестве `A={1,3,2,0,1,3}`.

# %%
A = {1,3,2,0,1,3}
z = len(A)
print (z) 
print ('Если |A| - мульти-множество то - 6')
# Out:
# 4
# Если |A| - мульти-множество то - 6

# %% [markdown]
# `A={1,3,4,7,10,11}`. Какие из множеств являются подмножествами множества A?
#
#
# `B={1,7,11}`
#
#
#
# `С={1,3,4,8}`
#
#
#
# `D={}`
#
#
#
# `E={1,3,4,7,10,11}`
#
#
#
# `F={1,3,4,5,7,10,11}`

# %%
A={1,3,4,7,10,11}
B={1,7,11}
C={1,3,4,8}
D={}
E={1,3,4,7,10,11}
F={1,3,4,5,7,10,11}

def isSub(x,y):
  if  isinstance(x,set) and x.issubset(y):
    return True
  else:
    return False  

array_sub = {'B': B,'C':C,'D':D,'E':E,'F':F}

for name,value in array_sub.items():
  if isSub(value,A):
    print (name)
# Out:
# B
# E

# %% [markdown]
# Дано множества `A={1,2,4,5,6}` и `B={1,2,3,5,7}`. Какое пересечение множеств А и В?
#
#
# `A∩B={1,3,5,7}`
#
#
#
# `A∩B={1,2,5}`
#
#
#
# `A∩B={1,2,3,4,5,6,7}`
#
#
#
# `A∩B={2,5}`

# %%
A={1,2,4,5,6}
B={1,2,3,5,7}

C = A & B
print ('A∩B =',C)
# Out:
# A∩B = {1, 2, 5}

# %% [markdown]
# Какое объединение множеств `A={1,2,4,5,7}` и `B={1,2,3,5,6}`?
#
#
# `A∪B={1,3,5,7}`
#
#
#
# `A∪B={1,2,5}`
#
#
#
# `A∪B={1,2,3,4,5,6,7}`
#
#
#
# `A∪B={1,2,4,5,7}`

# %%
A={1,2,4,5,7}
B={1,2,3,5,6}

C = A | B
print ('A∪B = ',C)
# Out:
# A∪B =  {1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# ### Часть 4

# %% [markdown]
# **Question 1**
#
# В нашем датасете 40 видео. Каждое видео принадлежит хотя бы одной категории -- комедии и мюзиклы. Есть 27 комедий и 22 мюзикла. Сколько видео относятся к обеим категориям одновременно?

# %%
len_A = 27 # комедии   |A|
len_B  = 22 # мюзиклы |B| 
# count  |A∩B|

count = len_A + len_B - 40
print (count)
# Out:
# 9

# %% [markdown]
# **Question 2**
#
# Сколько чисел от 1 к 1000 включительно делятся на 2 или на 3?

# %%
count_z = 0
for k in range(1000,0,-1):
  if k%2 ==0 and k%3 ==0:
    count_z += 1   
print (count_z)
# Out:
# 169

# %% [markdown]
# **Question 3**
#
# Сколько чисел от 1 к 1000 включительно не делятся на 2 и на 3?

# %%
count_z = 0
for k in range(1000,0,-1):
  if not k%2 ==0 and not k%3 ==0:
    count_z += 1   
print (count_z)
# Out:
# 502

# %% [markdown]
# ### Часть **5**

# %% [markdown]
# Сколько существует путей с точки `s` в точку `t`?

# %% [markdown]
# ![Cgrl6xANQRuK5esQDbEbKg_5155eedd370785f8376a9bb641071f41_number-of-paths.png](data:image/png;base64,...)

# %%
class Solution(object):
	def allPathsSourceTarget(self, graph):
		"""
		:type graph: List[List[int]]
		:rtype: List[List[int]]
		"""
		nodes_num = len(graph) # количесто узлов
		results = list() 
		path = list()
		from copy import deepcopy

		def dfs(node_id, graph, path, results):  # поиск в глубину
			path += [node_id]
			if node_id == nodes_num-1: 
				path_copy = deepcopy(path)
				results.append(path_copy)
			else: 
				for nxt_node_id in graph[node_id]: 
					dfs(nxt_node_id, graph, path, results)
			path.pop()

		dfs(0, graph, path, results) #
		return results

graph = [[1,2],[3,4],[3,5],[4,5,6],[6],[6],[]]
obj = Solution()
res = obj.allPathsSourceTarget(graph)
print ('Количество путей: ',len(res))
# Out:
# Количество путей:  8

# %% [markdown]
# ### Часть 6

# %% [markdown]
# У нас есть 7 разных датасетов по 12 записей в каждом. Сколько всего записей у нас?

# %%
84

# %% [markdown]
# Сколько у нас связей между точками?

# %% [markdown]
# ![3epIK9ygTKqqSCvcoLyqsg_82f188ee7536582e559b5aeaf7aa6faf_product_rule.png](data:image/png;base64,...)

# %%
42

# %% [markdown]
# ### Часть 7

# %% [markdown]
# ```
# for _ in range(4):
#         for _ in range(8):
#                 print("Hello world!")
# ```
#
# Сколько раз будет напечетана строка `"Hello world!"`?

# %%
k = 0
for _ in range(4):
        for _ in range(8):
                k +=1
print (k)
# Out:
# 32

# %% [markdown]
# ```
# for _ in range(2):
#         for _ in range(7):
#                 for _ in range(3):
#                         print("Hello world!")
# ```
#
#
#
# Сколько раз будет напечетана строка `"Hello world!"`?

# %%
k = 0
for _ in range(2):
        for _ in range(7):
                for _ in range(3):
                  k +=1
print (k)
# Out:
# 42

# %% [markdown]
# ```
# for _ in range(4):
#         for _ in range(4):
#                 print("Hello world!")
# for _ in range(7):
#         for _ in range(3):
#                 print("Hello world!")
# ```
#
# Сколько раз будет напечетана строка `"Hello world!"`?

# %%
37 # 4*4 + 7*3

# %% [markdown]
# ### Часть 8

# %% [markdown]
# Сколько 5-цифровых чисел можно создать из цифр 1, 2, 3, 4 и 5. Каждую цифру можно использовать только один раз.

# %%
5! # 5 ! / (5-5)! = 120

# %% [markdown]
# Сколько чисел от 0 до 9999 имеют в своем записи ровно одну 7 и одну 2?

# %%
# имея четырехзначные числа, если две цифры известны, вторые две можно выбрать 8*2=64 способами c включением 2 и 3-значных, где в старших разрядах нули.
# если ставим двойку на одно из 4-х мест и семерку на одно из 3-х, а из остальных 8-ми цифр составляем 8*8=64 комбинации. Получается всего 4*3*8*8 требуемых чисел = 786.


# Проверка формулы
t = range (9999)
print (t)

count = 0
for el in t:
  el_str = str(el)
  if '2' in el_str and  '7' in el_str and el_str.count('2')==1 and el_str.count('7')==1 :
    count +=1
  
print (count)
# Out:
# range(0, 9999)
# 768
